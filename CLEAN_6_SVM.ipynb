# %%
import mne
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from ev_parser import gesture_parser
from functools import partial
from scipy import interpolate
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, classification_report, make_scorer, accuracy_score, f1_score
from sklearn.pipeline import Pipeline
# %matplotlib inline

path_out = 'C:/skoltech_hand_writing'
subj = '' # enter subject id here

# %%
epochs_list_concated = mne.read_epochs(f'{path_out}/hand_writing/{subj}/5_files_for_model/epochs_eeg_2-epo.fif', preload = True)
epochs_eeg=epochs_list_concated.copy().resample(1000)
epochs_eeg_init=epochs_list_concated.copy().resample(1000)

# %%
# DEFINE CHANNELS TO PICK FOR THE MODEL IF DON'T WANT TO AVERAGE ALL EEG CHANNELS
# picks = [i for i in epochs_eeg.ch_names if 'L.vis' in i]
# picks = ['EEG L.vis_1', 'EEG L.vis_3', 'EEG L.lob_3', 'EEG L.lob_4', 'EEG L.lob_5', 'EEG L.lob_6', 'EEG L.lob_8', 'EEG R.vis_1',
        #  'EEG R.vis_5', 'EEG R.vis_6', 'EEG R.lob_6', 'EEG R.lob_7']
picks = [i for i in epochs_eeg.ch_names if 'EEG' in i]
epochs_filt = epochs_eeg.copy().pick(picks).filter(l_freq = 60, h_freq = 120)
# Out:
# Setting up band-pass filter from 60 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 60.00
# - Lower transition bandwidth: 15.00 Hz (-6 dB cutoff frequency: 52.50 Hz)
# - Upper passband edge: 120.00 Hz
# - Upper transition bandwidth: 30.00 Hz (-6 dB cutoff frequency: 135.00 Hz)
# - Filter length: 221 samples (0.221 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=1)]: Done 4607 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=1)]: Done 5201 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=1)]: Done 5831 tasks      | elapsed:    3.0s

# %%
epochs_filt
# Out:
# <EpochsFIF |  215 events (all good), -2 – 6.999 s, baseline off, ~442.9 MB, data loaded,
#  '0': 215>

# %%
# define X (eeg data of shape (n_epochs, n_times)) and y (target numbers that had to be written)
X = pd.DataFrame(epochs_filt.copy().get_data().mean(axis = 1))
y = pd.read_csv(f'{path_out}/hand_writing/{subj}/Digits_trials_final_2.xlsx')['Digit_text'].values
# random train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
# Out:
# C:\Users\proto\AppData\Local\Temp\ipykernel_17152\1392620339.py:1: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = pd.DataFrame(epochs_filt.copy().get_data().mean(axis = 1))

# %%
# PCA to reduce dimensionality
pca = PCA(n_components=30, random_state = 42)
pca.fit(X_train)
X_train_dec = pca.transform(X_train)
X_test_dec = pca.transform(X_test)
X_train_dec.shape, X_test_dec.shape
# Out:
# ((172, 30), (43, 30))

# %% [markdown]
# ### Make pipeline with a classifier, CV and grid search and metrics to find the best model

# %%
auc_scorer = make_scorer(
    score_func=roc_auc_score,
    needs_proba=True
)

estimators = [('svm', SVC(probability=True, random_state = 42, decision_function_shape='ovo'))]
param_grid = dict(svm__C = [.01, .1, 1, 10, 100],
                  svm__kernel = ['linear', 'rbf', 'sigmoid'],
                  svm__gamma = [.01, .1, 1, 10],
                  svm__random_state = [42],
                  )
pipe = Pipeline(estimators)
grid_search = GridSearchCV(
    pipe,
    param_grid=param_grid,
    cv=5,
    scoring = 'roc_auc_ovo_weighted', # THIS CAN BE CHANGED    
    verbose=10
)
grid_search.fit(X_train_dec, y_train)

print("Best parameter (CV score=%0.3f):" % grid_search.best_score_)
print(grid_search.best_params_)

best_estimator = grid_search.best_estimator_
best_estimator.fit(X_train_dec, y_train)
y_pred = best_estimator.predict_proba(X_test_dec)
print(f'ROC-AUC on a test sample: {roc_auc_score(y_test, y_pred, average='weighted', multi_class='ovo')}')
# Out:
# c:\Users\proto\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 1/5; 1/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 1/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 1/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 1/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 1/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 1/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.501 total time=   0.0s
# [CV 4/5; 1/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 1/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 1/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 1/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 2/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 2/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.443 total time=   0.0s
# [CV 2/5; 2/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 2/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.433 total time=   0.0s
# [CV 3/5; 2/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 2/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.490 total time=   0.0s
# [CV 4/5; 2/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 2/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.395 total time=   0.0s
# [CV 5/5; 2/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 2/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.609 total time=   0.0s
# [CV 1/5; 3/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 3/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.509 total time=   0.0s
# [CV 2/5; 3/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 3/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.562 total time=   0.0s
# [CV 3/5; 3/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 3/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.477 total time=   0.0s
# [CV 4/5; 3/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 3/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.373 total time=   0.0s
# [CV 5/5; 3/60] START svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 3/60] END svm__C=0.01, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.563 total time=   0.0s
# [CV 1/5; 4/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 4/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 4/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 4/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 4/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 4/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.501 total time=   0.0s
# [CV 4/5; 4/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 4/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 4/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 4/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 5/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 5/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 5/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 5/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 3/5; 5/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 5/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.484 total time=   0.0s
# [CV 4/5; 5/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 5/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.392 total time=   0.0s
# [CV 5/5; 5/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 5/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.615 total time=   0.0s
# [CV 1/5; 6/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 6/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.548 total time=   0.0s
# [CV 2/5; 6/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 6/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.581 total time=   0.0s
# [CV 3/5; 6/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 6/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.497 total time=   0.0s
# [CV 4/5; 6/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 6/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.400 total time=   0.0s
# [CV 5/5; 6/60] START svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 6/60] END svm__C=0.01, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.578 total time=   0.0s
# [CV 1/5; 7/60] START svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 7/60] END svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 7/60] START svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 7/60] END svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 7/60] START svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 7/60] END svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.501 total time=   0.0s
# [CV 4/5; 7/60] START svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 7/60] END svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 7/60] START svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 7/60] END svm__C=0.01, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 8/60] START svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 8/60] END svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.521 total time=   0.0s
# [CV 2/5; 8/60] START svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 8/60] END svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.602 total time=   0.0s
# [CV 3/5; 8/60] START svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 8/60] END svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.494 total time=   0.0s
# [CV 4/5; 8/60] START svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 8/60] END svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.423 total time=   0.0s
# [CV 5/5; 8/60] START svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 8/60] END svm__C=0.01, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.580 total time=   0.0s
# [CV 1/5; 9/60] START svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 9/60] END svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 9/60] START svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 9/60] END svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 9/60] START svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 9/60] END svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.501 total time=   0.0s
# [CV 4/5; 9/60] START svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 9/60] END svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 9/60] START svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 9/60] END svm__C=0.01, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 10/60] START svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 10/60] END svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 10/60] START svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 10/60] END svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 10/60] START svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 10/60] END svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.501 total time=   0.0s
# [CV 4/5; 10/60] START svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 10/60] END svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 10/60] START svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 10/60] END svm__C=0.01, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 11/60] START svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 11/60] END svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.584 total time=   0.0s
# [CV 2/5; 11/60] START svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 11/60] END svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.596 total time=   0.0s
# [CV 3/5; 11/60] START svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 11/60] END svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.514 total time=   0.0s
# [CV 4/5; 11/60] START svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 11/60] END svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.420 total time=   0.0s
# [CV 5/5; 11/60] START svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 11/60] END svm__C=0.01, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.599 total time=   0.0s
# [CV 1/5; 12/60] START svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 12/60] END svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.549 total time=   0.0s
# [CV 2/5; 12/60] START svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 12/60] END svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.586 total time=   0.0s
# [CV 3/5; 12/60] START svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 12/60] END svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 12/60] START svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 12/60] END svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 12/60] START svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 12/60] END svm__C=0.01, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 13/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 13/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 13/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 13/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.587 total time=   0.0s
# [CV 3/5; 13/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 13/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 13/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 13/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 13/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 13/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 14/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 14/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.440 total time=   0.0s
# [CV 2/5; 14/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 14/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.470 total time=   0.0s
# [CV 3/5; 14/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 14/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.489 total time=   0.0s
# [CV 4/5; 14/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 14/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.402 total time=   0.0s
# [CV 5/5; 14/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 14/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.605 total time=   0.0s
# [CV 1/5; 15/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 15/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.548 total time=   0.0s
# [CV 2/5; 15/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 15/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.581 total time=   0.0s
# [CV 3/5; 15/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 15/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.497 total time=   0.0s
# [CV 4/5; 15/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 15/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.400 total time=   0.0s
# [CV 5/5; 15/60] START svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 15/60] END svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.578 total time=   0.0s
# [CV 1/5; 16/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 16/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 16/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 16/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.587 total time=   0.0s
# [CV 3/5; 16/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 16/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 16/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 16/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 16/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 16/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 17/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 17/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 17/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 17/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.562 total time=   0.0s
# [CV 3/5; 17/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 17/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.479 total time=   0.0s
# [CV 4/5; 17/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 17/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.390 total time=   0.0s
# [CV 5/5; 17/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 17/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.612 total time=   0.0s
# [CV 1/5; 18/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 18/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.556 total time=   0.0s
# [CV 2/5; 18/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 18/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.588 total time=   0.0s
# [CV 3/5; 18/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 18/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.498 total time=   0.0s
# [CV 4/5; 18/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 18/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.406 total time=   0.0s
# [CV 5/5; 18/60] START svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 18/60] END svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 19/60] START svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 19/60] END svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 19/60] START svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 19/60] END svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.587 total time=   0.0s
# [CV 3/5; 19/60] START svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 19/60] END svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 19/60] START svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 19/60] END svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 19/60] START svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 19/60] END svm__C=0.1, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 20/60] START svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 20/60] END svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.514 total time=   0.0s
# [CV 2/5; 20/60] START svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 20/60] END svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.604 total time=   0.0s
# [CV 3/5; 20/60] START svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 20/60] END svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.498 total time=   0.0s
# [CV 4/5; 20/60] START svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 20/60] END svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.425 total time=   0.0s
# [CV 5/5; 20/60] START svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 20/60] END svm__C=0.1, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.582 total time=   0.0s
# [CV 1/5; 21/60] START svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 21/60] END svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 21/60] START svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 21/60] END svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.587 total time=   0.0s
# [CV 3/5; 21/60] START svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 21/60] END svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 21/60] START svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 21/60] END svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 21/60] START svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 21/60] END svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 22/60] START svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 22/60] END svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.557 total time=   0.0s
# [CV 2/5; 22/60] START svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 22/60] END svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.587 total time=   0.0s
# [CV 3/5; 22/60] START svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 22/60] END svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 4/5; 22/60] START svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 22/60] END svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.407 total time=   0.0s
# [CV 5/5; 22/60] START svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 22/60] END svm__C=0.1, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 23/60] START svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 23/60] END svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.523 total time=   0.0s
# [CV 2/5; 23/60] START svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 23/60] END svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.596 total time=   0.0s
# [CV 3/5; 23/60] START svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 23/60] END svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.493 total time=   0.0s
# [CV 4/5; 23/60] START svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 23/60] END svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.378 total time=   0.0s
# [CV 5/5; 23/60] START svm__C=0.1, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 5/5;
svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 44/60] END svm__C=10, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.428 total time=   0.0s
# [CV 5/5; 44/60] START svm__C=10, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 44/60] END svm__C=10, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.561 total time=   0.0s
# [CV 1/5; 45/60] START svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 45/60] END svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.530 total time=   0.0s
# [CV 2/5; 45/60] START svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 45/60] END svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.560 total time=   0.0s
# [CV 3/5; 45/60] START svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 45/60] END svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.480 total time=   0.0s
# [CV 4/5; 45/60] START svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 45/60] END svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.400 total time=   0.0s
# [CV 5/5; 45/60] START svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 45/60] END svm__C=10, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.586 total time=   0.0s
# [CV 1/5; 46/60] START svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 46/60] END svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.530 total time=   0.0s
# [CV 2/5; 46/60] START svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 46/60] END svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.560 total time=   0.0s
# [CV 3/5; 46/60] START svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 46/60] END svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.480 total time=   0.0s
# [CV 4/5; 46/60] START svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 46/60] END svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.400 total time=   0.0s
# [CV 5/5; 46/60] START svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 46/60] END svm__C=10, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.586 total time=   0.0s
# [CV 1/5; 47/60] START svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 47/60] END svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.534 total time=   0.0s
# [CV 2/5; 47/60] START svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 47/60] END svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.575 total time=   0.0s
# [CV 3/5; 47/60] START svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 47/60] END svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.496 total time=   0.0s
# [CV 4/5; 47/60] START svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 47/60] END svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.388 total time=   0.0s
# [CV 5/5; 47/60] START svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 47/60] END svm__C=10, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.597 total time=   0.0s
# [CV 1/5; 48/60] START svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 48/60] END svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 48/60] START svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 48/60] END svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 48/60] START svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 48/60] END svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 48/60] START svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 48/60] END svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 48/60] START svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 48/60] END svm__C=10, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 49/60] START svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 49/60] END svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 49/60] START svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 49/60] END svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 49/60] START svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 49/60] END svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 49/60] START svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 49/60] END svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 49/60] START svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 49/60] END svm__C=100, svm__gamma=0.01, svm__kernel=linear, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 50/60] START svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 50/60] END svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.442 total time=   0.0s
# [CV 2/5; 50/60] START svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 50/60] END svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.465 total time=   0.0s
# [CV 3/5; 50/60] START svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 50/60] END svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.485 total time=   0.0s
# [CV 4/5; 50/60] START svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 50/60] END svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.457 total time=   0.0s
# [CV 5/5; 50/60] START svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 50/60] END svm__C=100, svm__gamma=0.01, svm__kernel=rbf, svm__random_state=42;, score=0.613 total time=   0.0s
# [CV 1/5; 51/60] START svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 51/60] END svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.572 total time=   0.0s
# [CV 2/5; 51/60] START svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 51/60] END svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.577 total time=   0.0s
# [CV 3/5; 51/60] START svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 51/60] END svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.494 total time=   0.0s
# [CV 4/5; 51/60] START svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 51/60] END svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.388 total time=   0.0s
# [CV 5/5; 51/60] START svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 51/60] END svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 1/5; 52/60] START svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 52/60] END svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 52/60] START svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 52/60] END svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 52/60] START svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 52/60] END svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 52/60] START svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 52/60] END svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 52/60] START svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 52/60] END svm__C=100, svm__gamma=0.1, svm__kernel=linear, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 53/60] START svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 53/60] END svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.490 total time=   0.0s
# [CV 2/5; 53/60] START svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 53/60] END svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.616 total time=   0.0s
# [CV 3/5; 53/60] START svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 53/60] END svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.471 total time=   0.0s
# [CV 4/5; 53/60] START svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 53/60] END svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.358 total time=   0.0s
# [CV 5/5; 53/60] START svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 53/60] END svm__C=100, svm__gamma=0.1, svm__kernel=rbf, svm__random_state=42;, score=0.621 total time=   0.0s
# [CV 1/5; 54/60] START svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 54/60] END svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.530 total time=   0.0s
# [CV 2/5; 54/60] START svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 54/60] END svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.560 total time=   0.0s
# [CV 3/5; 54/60] START svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 54/60] END svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.480 total time=   0.0s
# [CV 4/5; 54/60] START svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 54/60] END svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.400 total time=   0.0s
# [CV 5/5; 54/60] START svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 54/60] END svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, svm__random_state=42;, score=0.586 total time=   0.0s
# [CV 1/5; 55/60] START svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 55/60] END svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 55/60] START svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 55/60] END svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 55/60] START svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 55/60] END svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 55/60] START svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 55/60] END svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 55/60] START svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 55/60] END svm__C=100, svm__gamma=1, svm__kernel=linear, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 56/60] START svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 56/60] END svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.503 total time=   0.0s
# [CV 2/5; 56/60] START svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 56/60] END svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.576 total time=   0.0s
# [CV 3/5; 56/60] START svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 56/60] END svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.483 total time=   0.0s
# [CV 4/5; 56/60] START svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 56/60] END svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.430 total time=   0.0s
# [CV 5/5; 56/60] START svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 56/60] END svm__C=100, svm__gamma=1, svm__kernel=rbf, svm__random_state=42;, score=0.561 total time=   0.0s
# [CV 1/5; 57/60] START svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 57/60] END svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 57/60] START svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 57/60] END svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 57/60] START svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 57/60] END svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 57/60] START svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 57/60] END svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 57/60] START svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 57/60] END svm__C=100, svm__gamma=1, svm__kernel=sigmoid, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 58/60] START svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 1/5; 58/60] END svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 58/60] START svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 2/5; 58/60] END svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 58/60] START svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 3/5; 58/60] END svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 58/60] START svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 4/5; 58/60] END svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 58/60] START svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42
# [CV 5/5; 58/60] END svm__C=100, svm__gamma=10, svm__kernel=linear, svm__random_state=42;, score=0.585 total time=   0.0s
# [CV 1/5; 59/60] START svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 1/5; 59/60] END svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.534 total time=   0.0s
# [CV 2/5; 59/60] START svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 2/5; 59/60] END svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.573 total time=   0.0s
# [CV 3/5; 59/60] START svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 3/5; 59/60] END svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.494 total time=   0.0s
# [CV 4/5; 59/60] START svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 4/5; 59/60] END svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.388 total time=   0.0s
# [CV 5/5; 59/60] START svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42
# [CV 5/5; 59/60] END svm__C=100, svm__gamma=10, svm__kernel=rbf, svm__random_state=42;, score=0.596 total time=   0.0s
# [CV 1/5; 60/60] START svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 1/5; 60/60] END svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.529 total time=   0.0s
# [CV 2/5; 60/60] START svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 2/5; 60/60] END svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.559 total time=   0.0s
# [CV 3/5; 60/60] START svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 3/5; 60/60] END svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.481 total time=   0.0s
# [CV 4/5; 60/60] START svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 4/5; 60/60] END svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.404 total time=   0.0s
# [CV 5/5; 60/60] START svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42
# [CV 5/5; 60/60] END svm__C=100, svm__gamma=10, svm__kernel=sigmoid, svm__random_state=42;, score=0.585 total time=   0.0s
# Best parameter (CV score=0.543):
# {'svm__C': 0.01, 'svm__gamma': 10, 'svm__kernel': 'rbf', 'svm__random_state': 42}
# ROC-AUC on a test sample: 0.5328872892826381
