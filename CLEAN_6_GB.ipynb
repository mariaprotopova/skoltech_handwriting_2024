# %%
import mne
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, classification_report, make_scorer, accuracy_score, f1_score
from sklearn.pipeline import Pipeline
# %matplotlib inline

path_out = 'C:/skoltech_hand_writing'
subj = 'S102'

# %%
epochs_list_concated = mne.read_epochs(f'{path_out}/hand_writing/{subj}/5_files_for_model/epochs_eeg_2-epo.fif', preload = True)
epochs_eeg=epochs_list_concated.copy().resample(1000)
epochs_eeg_init=epochs_list_concated.copy().resample(1000)
# Out:
# Reading C:\skoltech_hand_writing\hand_writing\S102\5_files_for_model\epochs_eeg_2-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -2000.00 ...    7000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 210 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
# DEFINE CHANNELS TO PICK FOR THE MODEL IF DON'T WANT TO AVERAGE ALL EEG CHANNELS
# picks = [i for i in epochs_eeg.ch_names if 'L.vis' in i]
# picks = ['EEG L.vis_1', 'EEG L.vis_3', 'EEG L.lob_3', 'EEG L.lob_4', 'EEG L.lob_5', 'EEG L.lob_6', 'EEG L.lob_8', 'EEG R.vis_1',
        #  'EEG R.vis_5', 'EEG R.vis_6', 'EEG R.lob_6', 'EEG R.lob_7']
picks = [i for i in epochs_eeg.ch_names if 'EEG' in i]
epochs_filt = epochs_eeg.copy().pick(picks).filter(l_freq = 60, h_freq = 120)
# Out:
# Setting up band-pass filter from 60 - 1.2e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 60.00
# - Lower transition bandwidth: 15.00 Hz (-6 dB cutoff frequency: 52.50 Hz)
# - Upper passband edge: 120.00 Hz
# - Upper transition bandwidth: 30.00 Hz (-6 dB cutoff frequency: 135.00 Hz)
# - Filter length: 221 samples (0.221 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=1)]: Done 4607 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=1)]: Done 5201 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=1)]: Done 5831 tasks      | elapsed:    3.7s

# %%
epochs_filt
# Out:
# <EpochsFIF |  210 events (all good), -2 – 6.999 s, baseline off, ~432.6 MB, data loaded,
#  '0': 210>

# %%
# define X (eeg data of shape (n_epochs, n_times)) and y (target numbers that had to be written)
X = pd.DataFrame(epochs_filt.copy().get_data().mean(axis = 1))
y = pd.read_csv(f'{path_out}/hand_writing/{subj}/Digits_trials_final_2.xlsx')['Digit_text'].values
# random train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42, stratify=y)
# Out:
# C:\Users\proto\AppData\Local\Temp\ipykernel_12388\4118362640.py:2: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   X = pd.DataFrame(epochs_filt.copy().get_data().mean(axis = 1))

# %%
# PCA to reduce dimensionality
pca = PCA(n_components=30, random_state = 42)
pca.fit(X_train)
X_train_dec = pca.transform(X_train)
X_test_dec = pca.transform(X_test)
X_train_dec.shape, X_test_dec.shape
# Out:
# ((168, 30), (42, 30))

# %% [markdown]
# ### Make pipeline with a classifier, CV and grid search and metrics to find the best model

# %%
auc_scorer = make_scorer(
    score_func=roc_auc_score,
    needs_proba=True
)

estimators = [('gb', GradientBoostingClassifier(random_state = 42))]
param_grid = dict(gb__learning_rate = [.01, .1, 1, 10],
                  gb__n_estimators = [10, 50, 100],
                  gb__ccp_alpha = [0, .01, .1, 1],
                  gb__random_state = [42],
                  )
pipe = Pipeline(estimators)
grid_search = GridSearchCV(
    pipe,
    param_grid=param_grid,
    cv=5,
    scoring = 'roc_auc_ovo_weighted', # THIS CAN BE CHANGED    
    verbose=10
)
grid_search.fit(X_train_dec, y_train)

print("Best parameter (CV score=%0.3f):" % grid_search.best_score_)
print(grid_search.best_params_)

best_estimator = grid_search.best_estimator_
best_estimator.fit(X_train_dec, y_train)
y_pred = best_estimator.predict_proba(X_test_dec)
print(f'ROC-AUC on a test sample: {roc_auc_score(y_test, y_pred, average='weighted', multi_class='ovo')}')
# Out:
# c:\Users\proto\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 1/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.492 total time=   0.1s
# [CV 2/5; 1/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 1/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.432 total time=   0.2s
# [CV 3/5; 1/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 1/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.534 total time=   0.1s
# [CV 4/5; 1/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 1/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.518 total time=   0.1s
# [CV 5/5; 1/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 1/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.523 total time=   0.1s
# [CV 1/5; 2/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 2/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.486 total time=   0.8s
# [CV 2/5; 2/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 2/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.484 total time=   0.8s
# [CV 3/5; 2/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 2/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.543 total time=   0.8s
# [CV 4/5; 2/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 2/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.495 total time=   0.8s
# [CV 5/5; 2/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 2/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.517 total time=   0.8s
# [CV 1/5; 3/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 3/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.511 total time=   1.6s
# [CV 2/5; 3/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 3/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.482 total time=   1.6s
# [CV 3/5; 3/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 3/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.534 total time=   1.6s
# [CV 4/5; 3/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 3/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.512 total time=   1.6s
# [CV 5/5; 3/48] START gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 3/48] END gb__ccp_alpha=0, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.531 total time=   1.5s
# [CV 1/5; 4/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 4/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.541 total time=   0.1s
# [CV 2/5; 4/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 4/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.486 total time=   0.1s
# [CV 3/5; 4/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 4/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.523 total time=   0.1s
# [CV 4/5; 4/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 4/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.514 total time=   0.1s
# [CV 5/5; 4/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 4/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.517 total time=   0.1s
# [CV 1/5; 5/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 5/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.583 total time=   0.7s
# [CV 2/5; 5/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 5/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.489 total time=   0.7s
# [CV 3/5; 5/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 5/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.532 total time=   0.7s
# [CV 4/5; 5/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 5/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.470 total time=   0.7s
# [CV 5/5; 5/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 5/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.511 total time=   0.7s
# [CV 1/5; 6/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 6/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.584 total time=   1.5s
# [CV 2/5; 6/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 6/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.510 total time=   1.6s
# [CV 3/5; 6/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 6/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.511 total time=   1.6s
# [CV 4/5; 6/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 6/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.471 total time=   1.5s
# [CV 5/5; 6/48] START gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 6/48] END gb__ccp_alpha=0, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.523 total time=   1.5s
# [CV 1/5; 7/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 7/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.506 total time=   0.1s
# [CV 2/5; 7/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 7/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.522 total time=   0.1s
# [CV 3/5; 7/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 7/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.527 total time=   0.1s
# [CV 4/5; 7/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 7/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.554 total time=   0.1s
# [CV 5/5; 7/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 7/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.501 total time=   0.1s
# [CV 1/5; 8/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 8/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.559 total time=   0.5s
# [CV 2/5; 8/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 8/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.526 total time=   0.4s
# [CV 3/5; 8/48] START gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 8/48] END gb__ccp_alpha=0, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0
, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 1/5; 34/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 34/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 2/5; 34/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 34/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 3/5; 34/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 34/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 4/5; 34/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 34/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 5/5; 34/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 34/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 1/5; 35/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 35/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 2/5; 35/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 35/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 3/5; 35/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 35/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 4/5; 35/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 35/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 5/5; 35/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 35/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 1/5; 36/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 36/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 2/5; 36/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 36/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 3/5; 36/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 36/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 4/5; 36/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 36/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 5/5; 36/48] START gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 36/48] END gb__ccp_alpha=0.1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 1/5; 37/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 37/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 2/5; 37/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 37/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 3/5; 37/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 37/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 4/5; 37/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 37/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 5/5; 37/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 37/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 1/5; 38/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 38/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 2/5; 38/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 38/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 3/5; 38/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 38/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 4/5; 38/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 38/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 5/5; 38/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 38/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.6s
# [CV 1/5; 39/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 39/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 2/5; 39/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 39/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 3/5; 39/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 39/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 4/5; 39/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 39/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 5/5; 39/48] START gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 39/48] END gb__ccp_alpha=1, gb__learning_rate=0.01, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 1/5; 40/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 40/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 2/5; 40/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 40/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 3/5; 40/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 40/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 4/5; 40/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 40/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 5/5; 40/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 40/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 1/5; 41/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 41/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 2/5; 41/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 41/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 3/5; 41/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 41/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 4/5; 41/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 41/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 5/5; 41/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 41/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 1/5; 42/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 42/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 2/5; 42/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 42/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 3/5; 42/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 42/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 4/5; 42/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 42/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 5/5; 42/48] START gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 42/48] END gb__ccp_alpha=1, gb__learning_rate=0.1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 1/5; 43/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 43/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 2/5; 43/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 43/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 3/5; 43/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 43/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 4/5; 43/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 43/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 5/5; 43/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 43/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 1/5; 44/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 44/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 2/5; 44/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 44/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 3/5; 44/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 44/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 4/5; 44/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 44/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 5/5; 44/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 44/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 1/5; 45/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 45/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 2/5; 45/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 45/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 3/5; 45/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 45/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 4/5; 45/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 45/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 5/5; 45/48] START gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 45/48] END gb__ccp_alpha=1, gb__learning_rate=1, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 1/5; 46/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 1/5; 46/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 2/5; 46/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 2/5; 46/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 3/5; 46/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 3/5; 46/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 4/5; 46/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 4/5; 46/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 5/5; 46/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42
# [CV 5/5; 46/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=10, gb__random_state=42;, score=0.500 total time=   0.1s
# [CV 1/5; 47/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 1/5; 47/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 2/5; 47/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 2/5; 47/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 3/5; 47/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 3/5; 47/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 4/5; 47/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 4/5; 47/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 5/5; 47/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42
# [CV 5/5; 47/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=50, gb__random_state=42;, score=0.500 total time=   0.7s
# [CV 1/5; 48/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 1/5; 48/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 2/5; 48/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 2/5; 48/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 3/5; 48/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 3/5; 48/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 4/5; 48/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 4/5; 48/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# [CV 5/5; 48/48] START gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42
# [CV 5/5; 48/48] END gb__ccp_alpha=1, gb__learning_rate=10, gb__n_estimators=100, gb__random_state=42;, score=0.500 total time=   1.4s
# Best parameter (CV score=0.531):
# {'gb__ccp_alpha': 0, 'gb__learning_rate': 1, 'gb__n_estimators': 50, 'gb__random_state': 42}
# ROC-AUC on a test sample: 0.5038139329805997
